# %%
import pandas as pd
import matplotlib.pyplot as plt
houses = pd.read_csv(r'C:\Users\Welcome\OneDrive\Pictures\Desktop\LEVEL 5\Task 3\Task 3 dataset.txt')
stats = houses[['price', 'sqft']].describe()
houses['price_per_sqft'] = houses['price'] / houses['sqft']
plt.figure(figsize=(8, 5))
plt.scatter(houses['sqft'], houses['price'])
plt.title('House Price vs Square Footage')
plt.xlabel('Square Feet')
plt.ylabel('Price ($)')
plt.grid(True)
plt.show()
print("First 5 rows with new column:")
print(houses.head())
# Out:
# First 5 rows with new column:
#     price  sqft  bedrooms  bathrooms  price_per_sqft
# 0  250000  1500         3        2.0      166.666667
# 1  320000  1800         4        2.0      177.777778
# 2  275000  1600         3        2.5      171.875000
# 3  400000  2200         4        3.0      181.818182
# 4  180000  1200         2        1.0      150.000000
