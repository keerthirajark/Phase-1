# %%
import pandas as pd
import numpy as np

# Step 1: Create a sample dataset
data = {
    'A': np.random.rand(10),
    'B': np.random.rand(10),
    'C': np.random.rand(10),
    'D': np.random.rand(10)
}

# Step 2: Convert the data into a DataFrame
df = pd.DataFrame(data)

# Step 3: Compute the correlation matrix
correlation_matrix = df.corr()

# Step 4: Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#           A         B         C         D
# A  1.000000  0.058792  0.420408  0.027358
# B  0.058792  1.000000  0.232606  0.201874
# C  0.420408  0.232606  1.000000 -0.345260
# D  0.027358  0.201874 -0.345260  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()
