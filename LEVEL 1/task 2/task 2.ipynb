# %%
pip install numpy matplotlib scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, uniform, binom, expon

# Set the seed for reproducibility
np.random.seed(42)

# Generate data for different distributions
# Normal Distribution
mu, sigma = 0, 1
normal_data = np.random.normal(mu, sigma, 1000)

# Uniform Distribution
low, high = 0, 10
uniform_data = np.random.uniform(low, high, 1000)

# Binomial Distribution
n, p = 10, 0.5
binomial_data = np.random.binomial(n, p, 1000)

# Exponential Distribution
lambda_ = 1.0
exponential_data = np.random.exponential(lambda_, 1000)

# Plotting the distributions
plt.figure(figsize=(14, 10))

# Normal Distribution
plt.subplot(2, 2, 1)
plt.hist(normal_data, bins=30, density=True, alpha=0.6, color='g')
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
plt.plot(x, norm.pdf(x, mu, sigma), 'r')
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Uniform Distribution
plt.subplot(2, 2, 2)
plt.hist(uniform_data, bins=30, density=True, alpha=0.6, color='b')
x = np.linspace(low, high, 100)
plt.plot(x, uniform.pdf(x, low, high-low), 'r')
plt.title('Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Binomial Distribution
plt.subplot(2, 2, 3)
plt.hist(binomial_data, bins=30, density=True, alpha=0.6, color='m')
x = np.arange(0, n+1)
plt.plot(x, binom.pmf(x, n, p), 'ro')
plt.title('Binomial Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

# Exponential Distribution
plt.subplot(2, 2, 4)
plt.hist(exponential_data, bins=30, density=True, alpha=0.6, color='c')
x = np.linspace(0, 5/lambda_, 100)
plt.plot(x, expon.pdf(x, scale=1/lambda_), 'r')
plt.title('Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Density')

plt.tight_layout()
plt.show()
